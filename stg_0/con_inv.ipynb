# %%
import numpy as np
import rabi_box as rb
import matplotlib.pyplot as plt

from scipy.special import factorial as fac

hbar,m_e,e = 1,1,1

# %matplotlib inline
plt.rcParams["font.family"] = "serif"
plt.rcParams['mathtext.fontset'] = 'dejavuserif'
plt.rcParams['mathtext.rm'] = 'dejavuserif'
plt.rcParams['mathtext.it'] = 'dejavuserif'
plt.rcParams['mathtext.bf'] = 'dejavuserif'

# %%
sig_figs = 4
t_range = np.linspace(0,30,1000)
n_bar = 5
lamb = 1#0.018384088893226454

fig,ax = plt.subplots(figsize=(20,10))

ax.plot(t_range, rb.w_sigfig(t_range,sig_figs,100,n_bar,lamb))
ax.axhline(y=0)

# %%
c_eg = (1,0)
det = 0
alpha = np.sqrt(n_bar)

c_n = rb.coherent_states

# %%
fig,ax = plt.subplots(figsize=(20,10))

ax.plot(t_range, rb.W(t_range,lamb,det,c_eg,c_n,20,alpha))
ax.plot(t_range, rb.W(t_range,lamb,det,c_eg,c_n,100,alpha))
ax.plot(t_range, rb.psi_mod(t_range,lamb,det,c_eg,c_n,20,alpha))
ax.plot(t_range, rb.psi_mod(t_range,lamb,det,c_eg,c_n,100,alpha))
ax.axhline(y=0)
# ax.set_ylim(-1.2,1.2)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-4-33c561a35a59> in <module>
#       1 fig,ax = plt.subplots(figsize=(20,10))
#       2
# ----> 3 ax.plot(t_range, rb.W(t_range,lamb,det,c_eg,c_n,20,alpha))
#       4 ax.plot(t_range, rb.W(t_range,lamb,det,c_eg,c_n,100,alpha))
#       5 ax.plot(t_range, rb.psi_mod(t_range,lamb,det,c_eg,c_n,20,alpha))
#
# ~/Documents/Uni/GFAM-JI/GFAM-JI/stg_0/rabi_box.py in W(t, lamb, det, c_eg, c_n, N, *args)
#     265
#     266 def W(t,lamb,det,c_eg,c_n,N=100,*args):
# --> 267     return psi_E(t,lamb,det,c_eg,c_n,N,*args) - psi_G(t,lamb,det,c_eg,c_n,N,*args)
#     268
#     269
#
# ~/Documents/Uni/GFAM-JI/GFAM-JI/stg_0/rabi_box.py in psi_E(t, lamb, det, c_eg, c_n, N, *args)
#     255
#     256     for n in range(N):
# --> 257         f1 = (sq_mod(Ce)*sq_mod(c_n(n,*args)) * np.cos(Sigma(n+1,lamb,det)*t/2)**2 + sq_mod(Cg)*sq_mod(c_n(n+1)) * np.sin(Sigma(n+1,lamb,det)*t/2)**2) * 4 * lamb**2 * (n+1) / Sigma(n+1,lamb,det)**2
#     258         f2 = sq_mod(Ce)*sq_mod(c_n(n,*args)) * det**2 / Sigma(n+1,lamb,det)**2
#     259         f3 = ((np.sin(Sigma(n+1,lamb,det)*t/2)*det/Sigma(n+1,lamb,det) + 1j * np.cos(Sigma(n+1,lamb,det)*t/2)) * Cg*c_n(n+1) * Ce.conjugate()*c_n(n,*args).conjugate()).real * 4*lamb*np.sqrt(n+1)/Sigma(n+1,lamb,det)
#
# ~/Documents/Uni/GFAM-JI/GFAM-JI/stg_0/rabi_box.py in coherent_states(n, *args)
#     275
#     276 def coherent_states(n,*args):
# --> 277     alpha = args[0]
#     278
#     279     exp = np.exp(- abs(alpha)**2 / 2)
#
# IndexError: tuple index out of range

# %%
# casos adicionales
c_eg_1 = (0,1)
c_eg_2 = (1/np.sqrt(2),1j*1/np.sqrt(2))

# %%
fig,ax = plt.subplots(figsize=(20,10))

ax.plot(t_range, rb.W(t_range,lamb,det,c_eg_1,c_n))
ax.plot(t_range, rb.psi_mod(t_range,lamb,det,c_eg_1,c_n))
ax.axhline(y=0)

# %%
fig,ax = plt.subplots(figsize=(20,10))

ax.plot(t_range, rb.W(t_range,lamb,det,c_eg_2,c_n))
ax.plot(t_range, rb.psi_mod(t_range,lamb,det,c_eg_2,c_n))
ax.axhline(y=0)

# %%
# con detuning
det1 = 0.2
det2 = 0.4
det3 = 0.8+0.5

# %%
fig,ax = plt.subplots(figsize=(20,10))

t_range = np.linspace(0,30,1000)

ax.plot(t_range, rb.W(t_range,lamb,det,c_eg,c_n,20),label=r"$\Delta = {}$".format(det))
# ax.plot(t_range, rb.W(t_range,lamb,det1,c_eg,c_n,2),label=r"$\Delta = {}$".format(det1))
# ax.plot(t_range, rb.W(t_range,lamb,det2,c_eg,c_n,2),label=r"$\Delta = {}$".format(det2))
# ax.plot(t_range, rb.W(t_range,lamb,det2,c_eg,c_n,2),label=r"$\Delta = {}$".format(det3))

ax.legend(frameon=False,fontsize=14)

ax.axhline(y=0)

# %%
fig,ax = plt.subplots(figsize=(20,10))

ax.plot(t_range, rb.W(t_range,lamb,det,c_eg_1,c_n),label=r"$\Delta = {}$".format(det))
ax.plot(t_range, rb.W(t_range,lamb,det,c_eg,c_n),label=r"$\Delta = {}$".format(det))
# ax.plot(t_range, rb.W(t_range,lamb,det1,c_eg_1,c_n),label=r"$\Delta = {}$".format(det1))
# ax.plot(t_range, rb.W(t_range,lamb,det2,c_eg_1,c_n),label=r"$\Delta = {}$".format(det2))
# ax.plot(t_range, rb.W(t_range,lamb,det2,c_eg_1,c_n),label=r"$\Delta = {}$".format(det3))

ax.legend(frameon=False,fontsize=14)

ax.axhline(y=0)

# %%
fig,ax = plt.subplots(figsize=(20,10))

ax.plot(t_range, rb.W(t_range,lamb,det,c_eg_2,c_n),label=r"$\Delta = {}$".format(det))
ax.plot(t_range, rb.W(t_range,lamb,det,c_eg_1,c_n),label=r"$\Delta = {}$".format(det))
# ax.plot(t_range, rb.W(t_range,lamb,det1,c_eg_2,c_n),label=r"$\Delta = {}$".format(det1))
# ax.plot(t_range, rb.W(t_range,lamb,det2,c_eg_2,c_n),label=r"$\Delta = {}$".format(det2))
# ax.plot(t_range, rb.W(t_range,lamb,det2,c_eg_2,c_n),label=r"$\Delta = {}$".format(det3))

ax.legend(frameon=False,fontsize=14)

ax.axhline(y=0)
