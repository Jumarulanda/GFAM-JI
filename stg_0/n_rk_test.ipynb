# %%
import rk_int as rk
import rabi_box as rb
import numpy as np
import matplotlib.pyplot as plt

hbar,m_e,e = 1,1,1

# %matplotlib inline
plt.rcParams["font.family"] = "serif"
plt.rcParams['mathtext.fontset'] = 'dejavuserif'
plt.rcParams['mathtext.rm'] = 'dejavuserif'
plt.rcParams['mathtext.it'] = 'dejavuserif'
plt.rcParams['mathtext.bf'] = 'dejavuserif'

# %%
q,E0,L = -1,0.1,5
t_lim = 300
dt = 0.05

c_0 = [1,0,0,0,0]

# %%
sol_d0_rk4 = rb.reim_noRWA_rk(1,2,0,q,E0,L,t_lim,dt,c_0,4)
# sol_d0_rk6 = rb.reim_noRWA_rk(1,2,0,q,E0,L,t_lim,dt,c_0,6)
# sol_d0_rk8 = rb.reim_noRWA_rk(1,2,0,q,E0,L,t_lim,dt,c_0,8)

# %%
p2_d0_rk4 = [sol[2][0]**2 + sol[3][0]**2 for sol in sol_d0_rk4]
# p2_d0_rk6 = [sol[2][0]**2 + sol[3][0]**2 for sol in sol_d0_rk6]
# p2_d0_rk8 = [sol[2][0]**2 + sol[3][0]**2 for sol in sol_d0_rk8]

t_rk = [sol[4][0] for sol in sol_d0_rk4]

# %%
plt.plot(t_rk,p2_d0_rk4)
# plt.plot(t_rk,p2_d0_rk6)
# plt.plot(t_rk,p2_d0_rk8)

# %%
c_comp_0 = [1,0,0]

# %%
sol_d0_rk4_C = rb.comp_noRWA_rk(1,2,0,q,E0,L,t_lim,dt,c_comp_0,4)
sol_d0_rk6_C = rb.comp_noRWA_rk(1,2,0,q,E0,L,t_lim,dt,c_comp_0,6)
sol_d0_rk8_C = rb.comp_noRWA_rk(1,2,0,q,E0,L,t_lim,dt,c_comp_0,8)

# %%
p2_d0_rk4_C = [float(sol[1][0].real**2 + sol[1][0].imag**2) for sol in sol_d0_rk4_C]
p2_d0_rk6_C = [float(sol[1][0].real**2 + sol[1][0].imag**2) for sol in sol_d0_rk6_C]
p2_d0_rk8_C = [float(sol[1][0].real**2 + sol[1][0].imag**2) for sol in sol_d0_rk8_C]

t_rk_C = [sol[-1][0] for sol in sol_d0_rk4_C]

# %%
plt.plot(t_rk_C,p2_d0_rk4_C)
plt.plot(t_rk_C,p2_d0_rk6_C)
plt.plot(t_rk_C,p2_d0_rk8_C)

plt.plot(t_rk,p2_d0_rk4)
plt.plot(t_rk,p2_d0_rk6)
plt.plot(t_rk,p2_d0_rk8)
# Out:
# /home/juan/.local/lib/python3.8/site-packages/numpy/core/_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
# same pob on both states

q,E0,L = -1,0.01,5
t_lim = 10
dt = 0.001

c_1 = [0,np.sqrt(0.5),0,np.sqrt(0.5),0]
c_comp_1 = [1j*np.sqrt(0.5),1j*np.sqrt(0.5),0]

# %%
sol_d0_rk4_sp = rb.reim_noRWA_rk(1,2,0,q,E0,L,t_lim,dt,c_1,4)
sol_d0_rk6_sp = rb.reim_noRWA_rk(1,2,0,q,E0,L,t_lim,dt,c_1,6)
sol_d0_rk8_sp = rb.reim_noRWA_rk(1,2,0,q,E0,L,t_lim,dt,c_1,8)

# %%
p2_d0_rk4_sp = [sol[2][0]**2 + sol[3][0]**2 for sol in sol_d0_rk4_sp]
p2_d0_rk6_sp = [sol[2][0]**2 + sol[3][0]**2 for sol in sol_d0_rk6_sp]
p2_d0_rk8_sp = [sol[2][0]**2 + sol[3][0]**2 for sol in sol_d0_rk8_sp]

t_rk_sp = [sol[-1][0] for sol in sol_d0_rk4_sp]

# %%
plt.plot(t_rk_sp,p2_d0_rk4_sp)
plt.plot(t_rk_sp,p2_d0_rk6_sp)
plt.plot(t_rk_sp,p2_d0_rk8_sp)

plt.ylim(0,1)
# Out:
# (0.0, 1.0)

# %%
sol_d0_rk4_C_sp = rb.comp_noRWA_rk(1,2,0,q,E0,L,t_lim,dt,c_comp_1,4)
sol_d0_rk6_C_sp = rb.comp_noRWA_rk(1,2,0,q,E0,L,t_lim,dt,c_comp_1,6)
sol_d0_rk8_C_sp = rb.comp_noRWA_rk(1,2,0,q,E0,L,t_lim,dt,c_comp_1,8)

# %%
p2_d0_rk4_C_sp = [float(sol[1][0].real**2 + sol[1][0].imag**2) for sol in sol_d0_rk4_C_sp]
p2_d0_rk6_C_sp = [float(sol[1][0].real**2 + sol[1][0].imag**2) for sol in sol_d0_rk6_C_sp]
p2_d0_rk8_C_sp = [float(sol[1][0].real**2 + sol[1][0].imag**2) for sol in sol_d0_rk8_C_sp]

t_rk_C_sp = [sol[-1][0] for sol in sol_d0_rk4_C_sp]

# %%
plt.plot(t_rk_C_sp,p2_d0_rk4_C_sp)
plt.plot(t_rk_C_sp,p2_d0_rk6_C_sp)
plt.plot(t_rk_C_sp,p2_d0_rk8_C_sp)
# Out:
# /home/juan/.local/lib/python3.8/site-packages/numpy/core/_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
