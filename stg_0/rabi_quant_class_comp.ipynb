# %%
import rk_int as rk
import rabi_box as rb
import numpy as np
import matplotlib.pyplot as plt

hbar,m_e,e = 1,1,1

# %matplotlib inline
plt.rcParams["font.family"] = "serif"
plt.rcParams['mathtext.fontset'] = 'dejavuserif'
plt.rcParams['mathtext.rm'] = 'dejavuserif'
plt.rcParams['mathtext.it'] = 'dejavuserif'
plt.rcParams['mathtext.bf'] = 'dejavuserif'

# %%
q,E0,L = -1,0.1,5

x_12 = rb.x_nm(1,2,L)
alpha_12 = rb.alpha(q,E0,x_12)
omega_12 = rb.omega_nm(2,1,L)

# %%
t = np.linspace(0,200,1000)
n = 5
lamb = rb.lamb(alpha_12,n)

fig,ax = plt.subplots()

det1 = 0

omega_Rq = rb.omega_q(det1,lamb,n)

ax.plot(t,rb.prob_2(t,det1,alpha_12))
ax.plot(t,rb.pe_q(t,omega_Rq,det1,lamb,n))

det2 = 0.1

omega_Rq = rb.omega_q(det2,lamb,n)

ax.plot(t,rb.prob_2(t,det2,alpha_12))
ax.plot(t,rb.pe_q(t,omega_Rq,det2,lamb,n))


det3 = 0.3

omega_Rq = rb.omega_q(det3,lamb,n)

ax.plot(t,rb.prob_2(t,det3,alpha_12))
ax.plot(t,rb.pe_q(t,omega_Rq,det3,lamb,n))


det4 = 0.5

omega_Rq = rb.omega_q(det4,lamb,n)

ax.plot(t,rb.prob_2(t,det4,alpha_12))
ax.plot(t,rb.pe_q(t,omega_Rq,det4,lamb,n))


print("lambda: {} \tE0: {} \tn: {}".format(lamb,E0,n))
# Out:
# lambda: 0.018384088893226454 	E0: 0.1 	n: 5

# %%
n = 50
lamb = rb.lamb(alpha_12,n)

fig,ax = plt.subplots()

det1 = 0

omega_Rq = rb.omega_q(det1,lamb,n)

ax.plot(t,rb.prob_2(t,det1,alpha_12))
ax.plot(t,rb.pe_q(t,omega_Rq,det1,lamb,n))

det2 = 0.1

omega_Rq = rb.omega_q(det2,lamb,n)

ax.plot(t,rb.prob_2(t,det2,alpha_12))
ax.plot(t,rb.pe_q(t,omega_Rq,det2,lamb,n))


det3 = 0.3

omega_Rq = rb.omega_q(det3,lamb,n)

ax.plot(t,rb.prob_2(t,det3,alpha_12))
ax.plot(t,rb.pe_q(t,omega_Rq,det3,lamb,n))


det4 = 0.5

omega_Rq = rb.omega_q(det4,lamb,n)

ax.plot(t,rb.prob_2(t,det4,alpha_12))
ax.plot(t,rb.pe_q(t,omega_Rq,det4,lamb,n))


print("lambda: {} \tE0: {} \tn: {}".format(lamb,E0,n))
# Out:
# lambda: 0.0063056904686448955 	E0: 0.1 	n: 50

# %%
n = 500
lamb = rb.lamb(alpha_12,n)

fig,ax = plt.subplots()

det1 = 0

omega_Rq = rb.omega_q(det1,lamb,n)

ax.plot(t,rb.prob_2(t,det1,alpha_12))
ax.plot(t,rb.pe_q(t,omega_Rq,det1,lamb,n))

det2 = 0.1

omega_Rq = rb.omega_q(det2,lamb,n)

ax.plot(t,rb.prob_2(t,det2,alpha_12))
ax.plot(t,rb.pe_q(t,omega_Rq,det2,lamb,n))


det3 = 0.3

omega_Rq = rb.omega_q(det3,lamb,n)

ax.plot(t,rb.prob_2(t,det3,alpha_12))
ax.plot(t,rb.pe_q(t,omega_Rq,det3,lamb,n))


det4 = 0.5

omega_Rq = rb.omega_q(det4,lamb,n)

ax.plot(t,rb.prob_2(t,det4,alpha_12))
ax.plot(t,rb.pe_q(t,omega_Rq,det4,lamb,n))


print("lambda: {} \tE0: {} \tn: {}".format(lamb,E0,n))
# Out:
# lambda: 0.002011865176951023 	E0: 0.1 	n: 500

# %%
d_op = q*x_12 
omegaE0 = lambda det: omega_12 + det

e0 = 1./(4*np.pi)

g = lambda det: -np.sqrt(omegaE0(det)/(e0*L**3))

lamb_p = lambda det: d_op*g(det)

# %%
det = 0.1
n = 1

rb.omega_q(det,lamb_p(det),n),rb.R_Omega(det,alpha_12)
# Out:
# (0.6793717727370893, 0.1345785769965534)

# %%
alpha_12**2/(4*lamb_p(0)**2) - 1
# Out:
# -0.9580058145401048

# %%
alpha_12,lamb_p(0)
# Out:
# (0.0900632743487447, 0.2197471015954145)
